# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df1 = pd.read_csv("D:\Data Science CAB\PJ\PJ2_Winery\winequality-red.csv", sep=';')
df2 = pd.read_csv("PJ2_Winery\winequality-white.csv", sep=';')
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6

# %%
red_wine = df1.copy()
white_wine = df2.copy()
display(red_wine.head(3), white_wine.head(3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Data Science CAB\PJ\project2.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science%20CAB/PJ/project2.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> red_wine = df1.copy()
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science%20CAB/PJ/project2.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> white_wine = df2.copy()
#
# NameError: name 'df1' is not defined

# %%
display(red_wine.info(), red_wine.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   wine_type             1599 non-null   object
#  1   fixed acidity         1599 non-null   float64
#  2   volatile acidity      1599 non-null   float64
#  3   citric acid           1599 non-null   float64
#  4   residual sugar        1599 non-null   float64
#  5   chlorides             1599 non-null   float64
#  6   free sulfur dioxide   1599 non-null   float64
#  7   total sulfur dioxide  1599 non-null   float64
#  8   density               1599 non-null   float64
#  9   pH                    1599 non-null   float64
#  10  sulphates             1599 non-null   float64
#  11  alcohol               1599 non-null   float64
#  12  quality               1599 non-null   int64
#  13  outliers              22 non-null     object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 175.0+ KB
# None
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
display(white_wine.describe(), white_wine.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   wine_type             4898 non-null   object
#  1   fixed acidity         4898 non-null   float64
#  2   volatile acidity      4898 non-null   float64
#  3   citric acid           4898 non-null   float64
#  4   residual sugar        4898 non-null   float64
#  5   chlorides             4898 non-null   float64
#  6   free sulfur dioxide   4898 non-null   float64
#  7   total sulfur dioxide  4898 non-null   float64
#  8   density               4898 non-null   float64
#  9   pH                    4898 non-null   float64
#  10  sulphates             4898 non-null   float64
#  11  alcohol               4898 non-null   float64
#  12  quality               4898 non-null   int64
#  13  outliers              30 non-null     object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 535.8+ KB
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000
# None

# %%
columns_for_descr = ['residual sugar','total sulfur dioxide','sulphates', 'alcohol','volatile acidity','quality']
pd.concat([red_wine[columns_for_descr].describe(), white_wine[columns_for_descr].describe()],axis=1, keys=['Red Wines Stats','White Wine Stats'])
# Out:
#       Red Wines Stats                                                 \
#        residual sugar total sulfur dioxide    sulphates      alcohol
# count     1599.000000          1599.000000  1599.000000  1599.000000
# mean         2.538806            46.467792     0.658149    10.422983
# std          1.409928            32.895324     0.169507     1.065668
# min          0.900000             6.000000     0.330000     8.400000
# 25%          1.900000            22.000000     0.550000     9.500000
# 50%          2.200000            38.000000     0.620000    10.200000
# 75%          2.600000            62.000000     0.730000    11.100000
# max         15.500000           289.000000     2.000000    14.900000
#
#                                     White Wine Stats                       \
#       volatile acidity      quality   residual sugar total sulfur dioxide
# count      1599.000000  1599.000000      4898.000000          4898.000000
# mean          0.527821     5.636023         6.391415           138.360657
# std           0.179060     0.807569         5.072058            42.498065
# min           0.120000     3.000000         0.600000             9.000000
# 25%           0.390000     5.000000         1.700000           108.000000
# 50%           0.520000     6.000000         5.200000           134.000000
# 75%           0.640000     6.000000         9.900000           167.000000
# max           1.580000     8.000000        65.800000           440.000000
#
#
#          sulphates      alcohol volatile acidity      quality
# count  4898.000000  4898.000000      4898.000000  4898.000000
# mean      0.489847    10.514267         0.278241     5.877909
# std       0.114126     1.230621         0.100795     0.885639
# min       0.220000     8.000000         0.080000     3.000000
# 25%       0.410000     9.500000         0.210000     5.000000
# 50%       0.470000    10.400000         0.260000     6.000000
# 75%       0.550000    11.400000         0.320000     6.000000
# max       1.080000    14.200000         1.100000     9.000000

# %%
red_wine.sort_values(by='pH', ascending=False)
#.head(20) .tail(10)
# Out:
#      wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1316  red wine            5.4             0.740         0.00             1.2
# 1321  red wine            5.0             0.740         0.00             1.2
# 695   red wine            5.1             0.470         0.02             1.3
# 45    red wine            4.6             0.520         0.15             2.1
# 95    red wine            4.7             0.600         0.17             2.3
# ...        ...            ...               ...          ...             ...
# 440   red wine           12.6             0.310         0.72             2.2
# 1470  red wine           10.0             0.690         0.11             1.4
# 614   red wine            9.2             0.755         0.18             2.2
# 544   red wine           14.3             0.310         0.74             1.8
# 151   red wine            9.2             0.520         1.00             3.4
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1316      0.041                 16.0                  46.0  0.99258  4.01
# 1321      0.041                 16.0                  46.0  0.99258  4.01
# 695       0.034                 18.0                  44.0  0.99210  3.90
# 45        0.054                  8.0                  65.0  0.99340  3.90
# 95        0.058                 17.0                 106.0  0.99320  3.85
# ...         ...                  ...                   ...      ...   ...
# 440       0.072                  6.0                  29.0  0.99870  2.88
# 1470      0.084                  8.0                  24.0  0.99578  2.88
# 614       0.148                 10.0                 103.0  0.99690  2.87
# 544       0.075                  6.0                  15.0  1.00080  2.86
# 151       0.610                 32.0                  69.0  0.99960  2.74
#
#       sulphates  alcohol  quality      outliers
# 1316       0.59     12.5        6  highest_2 Ph
# 1321       0.59     12.5        6  highest_2 Ph
# 695        0.62     12.8        6           NaN
# 45         0.56     13.1        4           NaN
# 95         0.60     12.9        6           NaN
# ...         ...      ...      ...           ...
# 440        0.82      9.8        8    lower_9 Ph
# 1470       0.47      9.7        5    lower_9 Ph
# 614        1.36     10.2        6    lower_9 Ph
# 544        0.79      8.4        6    lower_9 Ph
# 151        2.00      9.4        4    lower_9 Ph
#
# [1599 rows x 14 columns]

# %%
white_wine_highsugar = white_wine[(white_wine['residual sugar'] >= 9.9)&(white_wine['total sulfur dioxide'] > 210)]
white_wine_highsugar.sort_values(by='total sulfur dioxide', ascending=False).head(1)
#.head(20) .tail(10)
# Out:
#        wine_type  fixed acidity  volatile acidity  citric acid  \
# 1417  white wine            8.6              0.55         0.35
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 1417           15.55      0.057                 35.5                 366.5
#
#       density    pH  sulphates  alcohol  quality                   outliers
# 1417   1.0001  3.04       0.63     11.0        3  total sulfur dioxide >300

# %%
white_wine.sort_values(by='alcohol', ascending=False).tail(10)
# Out:
#        wine_type  fixed acidity  volatile acidity  citric acid  \
# 294   white wine            9.1             0.590         0.38
# 2268  white wine            6.3             0.200         0.30
# 4014  white wine            6.5             0.180         0.48
# 4073  white wine            6.5             0.360         0.16
# 4018  white wine            6.4             0.180         0.48
# 3835  white wine            6.2             0.310         0.23
# 3839  white wine            6.2             0.310         0.23
# 4020  white wine            6.4             0.370         0.12
# 3265  white wine            4.2             0.215         0.23
# 2625  white wine            4.5             0.190         0.21
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 294             1.60      0.066                 34.0                 182.0
# 2268            5.90      0.034                 35.0                 152.0
# 4014           18.00      0.054                 56.0                 183.0
# 4073            1.30      0.054                 11.0                 107.0
# 4018           18.00      0.054                 56.0                 183.0
# 3835            3.30      0.052                 34.0                 113.0
# 3839            3.30      0.052                 34.0                 113.0
# 4020            5.90      0.056                  6.0                  91.0
# 3265            5.10      0.041                 64.0                 157.0
# 2625            0.95      0.033                 89.0                 159.0
#
#       density    pH  sulphates  alcohol  quality      outliers
# 294   0.99680  3.23       0.38      8.5        3           NaN
# 2268  0.99642  3.47       0.40      8.5        6           NaN
# 4014  1.00038  2.98       0.61      8.5        6           NaN
# 4073  0.99398  3.19       0.39      8.5        5           NaN
# 4018  1.00038  2.98       0.61      8.5        6           NaN
# 3835  0.99429  3.16       0.48      8.4        5           NaN
# 3839  0.99429  3.16       0.48      8.4        5           NaN
# 4020  0.99536  3.06       0.46      8.4        4           NaN
# 3265  0.99688  3.42       0.44      8.0        3  min2 alcohol
# 2625  0.99332  3.34       0.42      8.0        5  min2 alcohol

# %%
#marking outliers red_wine
red_wine['outliers'] = np.nan
#outliers with total sulfur dioxide in red wine (more then 160)
red_wine.loc[red_wine['total sulfur dioxide'] > 160, 'outliers'] = 'total sulfur dioxide too high'
red_wine.loc[red_wine['volatile acidity'] > 1.2, 'outliers'] = 'max4 of volatile acidity'
red_wine.loc[red_wine['residual sugar'] > 15.0, 'outliers'] = 'max3 of residual sugar'
red_wine.loc[red_wine['alcohol'] > 14.0, 'outliers'] = 'max of alcohol'
red_wine.loc[red_wine['pH'] < 2.9, 'outliers'] = 'lower_9 Ph'
red_wine.loc[red_wine['pH'] > 4, 'outliers'] = 'highest_2 Ph'


red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality outliers
# 0      9.4        5      NaN
# 1      9.8        5      NaN
# 2      9.8        5      NaN
# 3      9.8        6      NaN
# 4      9.4        5      NaN

# %%
white_wine.sort_values(by='chlorides', ascending=False)
#.head(20) .tail(10)
# Out:
#        wine_type  fixed acidity  volatile acidity  citric acid  \
# 484   white wine            6.2              0.37         0.30
# 1217  white wine            8.0              0.61         0.38
# 687   white wine            6.8              0.67         0.30
# 4473  white wine            7.1              0.36         0.20
# 1865  white wine            7.6              0.36         0.44
# ...          ...            ...               ...          ...
# 3638  white wine            6.4              0.29         0.32
# 2578  white wine            5.8              0.30         0.27
# 3901  white wine            4.8              0.65         0.12
# 2631  white wine            6.7              0.28         0.28
# 3773  white wine            5.0              0.61         0.12
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 484              6.6      0.346                 79.0                 200.0
# 1217            12.1      0.301                 24.0                 220.0
# 687             13.0      0.290                 22.0                 193.0
# 4473             1.6      0.271                 24.0                 140.0
# 1865             8.3      0.255                 28.0                 142.0
# ...              ...        ...                  ...                   ...
# 3638             2.4      0.014                 34.0                  89.0
# 2578             1.7      0.014                 45.0                 104.0
# 3901             1.1      0.013                  4.0                  10.0
# 2631             2.4      0.012                 36.0                 100.0
# 3773             1.3      0.009                 65.0                 100.0
#
#       density    pH  sulphates  alcohol  quality outliers
# 484   0.99540  3.29       0.58      9.6        5      NaN
# 1217  0.99930  2.94       0.48      9.2        5      NaN
# 687   0.99840  3.08       0.67      9.0        4      NaN
# 4473  0.99356  3.11       0.63      9.8        5      NaN
# 1865  0.99580  3.12       0.43     10.2        6      NaN
# ...       ...   ...        ...      ...      ...      ...
# 3638  0.99008  3.24       0.66     12.5        7      NaN
# 2578  0.98914  3.40       0.56     12.6        7      NaN
# 3901  0.99246  3.32       0.36     13.5        4      NaN
# 2631  0.99064  3.26       0.39     11.7        7      NaN
# 3773  0.98740  3.26       0.37     13.5        5      NaN
#
# [4898 rows x 14 columns]

# %%
#marking outliers white_wine
white_wine['outliers'] = np.nan
white_wine.head()
white_wine.loc[white_wine['quality'] == 9 , 'outliers'] = 'top 5 guality'
white_wine.loc[white_wine['volatile acidity'] > 0.95 , 'outliers'] = 'top3 vol.acidity in WW'
white_wine.loc[white_wine['citric acid'] > 1 , 'outliers'] = 'top2 citric acid'
white_wine.loc[white_wine['citric acid'] > 1 , 'outliers'] = 'top3 vol.acidity in WW&'
white_wine.loc[white_wine['total sulfur dioxide'] > 300 , 'outliers'] = 'total sulfur dioxide >300'
white_wine.loc[white_wine['sulphates'] >= 0.99 , 'outliers'] ='top5 sulphates'
white_wine.loc[white_wine['alcohol'] >= 14.00 , 'outliers'] = 'top7 alcohol'
white_wine.loc[white_wine['alcohol'] == 8.00 , 'outliers'] = 'min2 alcohol'

# %%
#defining a type of wine to join the databases afterwards
red_wine_type = 'red wine'
white_wine_type = 'white wine'
red_wine.insert(0, 'wine_type', red_wine_type)
white_wine.insert(0, 'wine_type', white_wine_type)

# %%
#drop wine_type colums
# red_wine = red_wine.drop('wine_type', axis=1)
# white_wine = white_wine.drop('wine_type', axis=1)

# %%
filt_white = white_wine[pd.notna(white_wine['outliers'])]
filt_red = red_wine[pd.notna(red_wine['outliers'])]

pd.concat([filt_red, filt_white], axis = 0)
# Out:
#        wine_type  fixed acidity  volatile acidity  citric acid  \
# 126     red wine            8.2             1.330         0.00
# 127     red wine            8.1             1.330         0.00
# 151     red wine            9.2             0.520         1.00
# 354     red wine            6.1             0.210         0.40
# 440     red wine           12.6             0.310         0.72
# 480     red wine           10.6             0.280         0.39
# 544     red wine           14.3             0.310         0.74
# 614     red wine            9.2             0.755         0.18
# 650     red wine           10.7             0.430         0.39
# 652     red wine           15.9             0.360         0.65
# 656     red wine           10.7             0.430         0.39
# 672     red wine            9.8             1.240         0.34
# 1017    red wine            8.0             0.180         0.37
# 1018    red wine            8.0             0.180         0.37
# 1079    red wine            7.9             0.300         0.68
# 1081    red wine            7.9             0.300         0.68
# 1299    red wine            7.6             1.580         0.00
# 1316    red wine            5.4             0.740         0.00
# 1321    red wine            5.0             0.740         0.00
# 1434    red wine           10.2             0.540         0.37
# 1435    red wine           10.2             0.540         0.37
# 1470    red wine           10.0             0.690         0.11
# 325   white wine            7.5             0.270         0.31
# 745   white wine            7.4             0.200         1.66
# 774   white wine            9.1             0.270         0.45
# 820   white wine            6.6             0.360         0.29
# 827   white wine            7.4             0.240         0.36
# 876   white wine            6.9             0.360         0.34
# 1099  white wine            5.8             0.290         0.21
# 1417  white wine            8.6             0.550         0.35
# 1605  white wine            7.1             0.260         0.49
# 1931  white wine            7.1             0.490         0.22
# 1951  white wine            9.9             1.005         0.46
# 2127  white wine            9.1             0.330         0.38
# 2441  white wine            7.2             0.200         0.28
# 2625  white wine            4.5             0.190         0.21
# 2654  white wine            6.9             0.400         0.22
# 2668  white wine            9.6             0.655         0.21
# 2781  white wine            7.8             0.965         0.60
# 2874  white wine            5.4             0.230         0.36
# 2945  white wine            4.9             0.330         0.31
# 3150  white wine            5.8             0.390         0.47
# 3152  white wine            7.6             0.250         1.23
# 3265  white wine            4.2             0.215         0.23
# 3904  white wine            5.0             0.455         0.18
# 3915  white wine            4.7             0.455         0.18
# 3918  white wine            6.4             0.350         0.28
# 4039  white wine            6.1             1.100         0.16
# 4503  white wine            5.8             0.610         0.01
# 4582  white wine            6.3             0.370         0.51
# 4745  white wine            6.1             0.260         0.25
# 4886  white wine            6.2             0.210         0.28
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 126             1.70      0.081                  3.0                  12.0
# 127             1.80      0.082                  3.0                  12.0
# 151             3.40      0.610                 32.0                  69.0
# 354             1.40      0.066                 40.5                 165.0
# 440             2.20      0.072                  6.0                  29.0
# 480            15.50      0.069                  6.0                  23.0
# 544             1.80      0.075                  6.0                  15.0
# 614             2.20      0.148                 10.0                 103.0
# 650             2.20      0.106                  8.0                  32.0
# 652             7.50      0.096                 22.0                  71.0
# 656             2.20      0.106                  8.0                  32.0
# 672             2.00      0.079                 32.0                 151.0
# 1017            0.90      0.049                 36.0                 109.0
# 1018            0.90      0.049                 36.0                 109.0
# 1079            8.30      0.050                 37.5                 278.0
# 1081            8.30      0.050                 37.5                 289.0
# 1299            2.10      0.137                  5.0                   9.0
# 1316            1.20      0.041                 16.0                  46.0
# 1321            1.20      0.041                 16.0                  46.0
# 1434           15.40      0.214                 55.0                  95.0
# 1435           15.40      0.214                 55.0                  95.0
# 1470            1.40      0.084                  8.0                  24.0
# 325             5.80      0.057                131.0                 313.0
# 745             2.10      0.022                 34.0                 113.0
# 774            10.60      0.035                 28.0                 124.0
# 820             1.60      0.021                 24.0                  85.0
# 827             2.00      0.031                 27.0                 139.0
# 876             4.20      0.018                 57.0                 119.0
# 1099            2.60      0.025                 12.0                 120.0
# 1417           15.55      0.057                 35.5                 366.5
# 1605            2.20      0.032                 31.0                 113.0
# 1931            2.00      0.047                146.5                 307.5
# 1951            1.40      0.046                 34.0                 185.0
# 2127            1.70      0.062                 50.5                 344.0
# 2441            1.60      0.028                 13.0                 168.0
# 2625            0.95      0.033                 89.0                 159.0
# 2654            5.95      0.081                 76.0                 303.0
# 2668            2.00      0.039                 21.0                 120.0
# 2781           65.80      0.074                  8.0                 160.0
# 2874            1.50      0.030                 74.0                 121.0
# 2945            1.20      0.016                 39.0                 150.0
# 3150            7.50      0.027                 12.0                  88.0
# 3152            4.60      0.035                 51.0                 294.0
# 3265            5.10      0.041                 64.0                 157.0
# 3904            1.90      0.036                 33.0                 106.0
# 3915            1.90      0.036                 33.0                 106.0
# 3918            1.60      0.037                 31.0                 113.0
# 4039            4.40      0.033                  8.0                 109.0
# 4503            8.40      0.041                 31.0                 104.0
# 4582            6.30      0.048                 35.0                 146.0
# 4745            2.90      0.047                289.0                 440.0
# 4886            5.70      0.028                 45.0                 121.0
#
#       density    pH  sulphates  alcohol  quality  \
# 126   0.99640  3.53       0.49    10.90        5
# 127   0.99640  3.54       0.48    10.90        5
# 151   0.99960  2.74       2.00     9.40        4
# 354   0.99120  3.25       0.59    11.90        6
# 440   0.99870  2.88       0.82     9.80        8
# 480   1.00260  3.12       0.66     9.20        5
# 544   1.00080  2.86       0.79     8.40        6
# 614   0.99690  2.87       1.36    10.20        6
# 650   0.99860  2.89       0.50     9.60        5
# 652   0.99760  2.98       0.84    14.90        5
# 656   0.99860  2.89       0.50     9.60        5
# 672   0.99800  3.15       0.53     9.50        5
# 1017  0.99007  2.89       0.44    12.70        6
# 1018  0.99007  2.89       0.44    12.70        6
# 1079  0.99316  3.01       0.51    12.30        7
# 1081  0.99316  3.01       0.51    12.30        7
# 1299  0.99476  3.50       0.40    10.90        3
# 1316  0.99258  4.01       0.59    12.50        6
# 1321  0.99258  4.01       0.59    12.50        6
# 1434  1.00369  3.18       0.77     9.00        6
# 1435  1.00369  3.18       0.77     9.00        6
# 1470  0.99578  2.88       0.47     9.70        5
# 325   0.99460  3.18       0.59    10.50        5
# 745   0.99165  3.26       0.55    12.20        6
# 774   0.99700  3.20       0.46    10.40        9
# 820   0.98965  3.41       0.61    12.40        9
# 827   0.99055  3.28       0.48    12.50        9
# 876   0.98980  3.28       0.36    12.70        9
# 1099  0.98940  3.39       0.79    14.00        7
# 1417  1.00010  3.04       0.63    11.00        3
# 1605  0.99030  3.37       0.42    12.90        9
# 1931  0.99240  3.24       0.37    11.00        3
# 1951  0.99660  3.02       0.49    10.20        4
# 2127  0.99580  3.10       0.70     9.50        5
# 2441  0.99203  3.17       1.06    11.50        6
# 2625  0.99332  3.34       0.42     8.00        5
# 2654  0.99705  3.40       0.57     9.40        5
# 2668  0.99188  3.00       1.00    12.60        6
# 2781  1.03898  3.39       0.69    11.70        6
# 2874  0.98976  3.24       0.99    12.10        7
# 2945  0.98713  3.33       0.59    14.00        8
# 3150  0.99070  3.38       0.45    14.00        6
# 3152  0.99018  3.03       0.43    13.10        6
# 3265  0.99688  3.42       0.44     8.00        3
# 3904  0.98746  3.21       0.83    14.00        7
# 3915  0.98746  3.21       0.83    14.00        7
# 3918  0.98779  3.12       0.40    14.20        7
# 4039  0.99058  3.35       0.47    12.40        4
# 4503  0.99090  3.26       0.72    14.05        7
# 4582  0.99430  3.10       1.01    10.50        6
# 4745  0.99314  3.44       0.64    10.50        3
# 4886  0.99168  3.21       1.08    12.15        7
#
#                            outliers
# 126        max4 of volatile acidity
# 127        max4 of volatile acidity
# 151                      lower_9 Ph
# 354   total sulfur dioxide too high
# 440                      lower_9 Ph
# 480          max3 of residual sugar
# 544                      lower_9 Ph
# 614                      lower_9 Ph
# 650                      lower_9 Ph
# 652                  max of alcohol
# 656                      lower_9 Ph
# 672        max4 of volatile acidity
# 1017                     lower_9 Ph
# 1018                     lower_9 Ph
# 1079  total sulfur dioxide too high
# 1081  total sulfur dioxide too high
# 1299       max4 of volatile acidity
# 1316                   highest_2 Ph
# 1321                   highest_2 Ph
# 1434         max3 of residual sugar
# 1435         max3 of residual sugar
# 1470                     lower_9 Ph
# 325       total sulfur dioxide >300
# 745         top3 vol.acidity in WW&
# 774                   top 5 guality
# 820                   top 5 guality
# 827                   top 5 guality
# 876                   top 5 guality
# 1099                   top7 alcohol
# 1417      total sulfur dioxide >300
# 1605                  top 5 guality
# 1931      total sulfur dioxide >300
# 1951         top3 vol.acidity in WW
# 2127      total sulfur dioxide >300
# 2441                 top5 sulphates
# 2625                   min2 alcohol
# 2654      total sulfur dioxide >300
# 2668                 top5 sulphates
# 2781         top3 vol.acidity in WW
# 2874                 top5 sulphates
# 2945                   top7 alcohol
# 3150                   top7 alcohol
# 3152        top3 vol.acidity in WW&
# 3265                   min2 alcohol
# 3904                   top7 alcohol
# 3915                   top7 alcohol
# 3918                   top7 alcohol
# 4039         top3 vol.acidity in WW
# 4503                   top7 alcohol
# 4582                 top5 sulphates
# 4745      total sulfur dioxide >300
# 4886                 top5 sulphates

# %%
# Creating a column 'quality wine' and dividing into 3 categories
cond_rw = [
    red_wine['quality'] > 7,
    red_wine['quality'] > 5,
    red_wine['quality'] > 1]
values = [
    'higher quality',
    'medium quality',
    'lower quality']
red_wine['quality_category'] = np.select(cond_rw, values, default=np.nan)

cond_ww = [
    white_wine['quality'] > 7,
    white_wine['quality'] > 5,
    white_wine['quality'] > 1]
white_wine['quality_category'] = np.select(cond_ww, values, default=np.nan)

# %%
display(red_wine.head(), white_wine.head())
# Out:
#   wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  red wine            7.4              0.70         0.00             1.9
# 1  red wine            7.8              0.88         0.00             2.6
# 2  red wine            7.8              0.76         0.04             2.3
# 3  red wine           11.2              0.28         0.56             1.9
# 4  red wine            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality outliers quality_category
# 0       0.56      9.4        5      NaN    lower quality
# 1       0.68      9.8        5      NaN    lower quality
# 2       0.65      9.8        5      NaN    lower quality
# 3       0.58      9.8        6      NaN   medium quality
# 4       0.56      9.4        5      NaN    lower quality
#     wine_type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white wine            7.0              0.27         0.36            20.7
# 1  white wine            6.3              0.30         0.34             1.6
# 2  white wine            8.1              0.28         0.40             6.9
# 3  white wine            7.2              0.23         0.32             8.5
# 4  white wine            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality outliers quality_category
# 0       0.45      8.8        6      NaN   medium quality
# 1       0.49      9.5        6      NaN   medium quality
# 2       0.44     10.1        6      NaN   medium quality
# 3       0.40      9.9        6      NaN   medium quality
# 4       0.40      9.9        6      NaN   medium quality

# %%
hist1 = sns.histplot(data=red_wine, x='quality_category', color="darkred")
#plt.ylim(0, 3000)
# plt.bar('Quality Category', 'Count')
plt.xlabel('Quality Category')
plt.ylabel('Count')
plt.title('Distribution of Quality Categories in Red Wine')
# Out:
# Text(0.5, 1.0, 'Distribution of Quality Categories in Red Wine')

# %%
hist2 = sns.histplot(data=white_wine, x='quality_category', color="lightyellow")
# plt.bar('Quality Category', 'Count')
plt.xlabel('Quality Category')
plt.ylabel('Count')
plt.title('Distribution of Quality Categories in White Wine')
# Out:
# Text(0.5, 1.0, 'Distribution of Quality Categories in White Wine')

# %%
fig, (hist1, hist2) = plt.subplots(1, 2, figsize=(12, 4))
plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot the first histogram on the first subplot
sns.histplot(data=red_wine, x='quality_category', color="darkred", ax=ax1)
ax1.set_xlabel('Quality Category')
ax1.set_ylabel('Count')
ax1.set_title('Distribution of Quality Categories in Red Wine')

# Plot the second histogram on the second subplot
sns.histplot(data=white_wine, x='quality_category', color="lightyellow", ax=ax2)
ax2.set_xlabel('Quality Category')
ax2.set_ylabel('Count')
ax2.set_title('Distribution of Quality Categories in White Wine')

ax1.set_ylim(0, 3200) 


plt.tight_layout()
plt.show()

# %%
sns.histplot(data=combined_wine, x='total_sulfur_dioxide', hue="quality_label")
